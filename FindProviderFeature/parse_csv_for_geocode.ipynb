# %%
import pandas as pd
import numpy as np
import time
import glob
import os
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database
from sqlalchemy.engine import URL
import psycopg2
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Read in filtered provider CSV

# %%
col = ['NPI', 'LastName', 'FirstName', 'MiddleName', 'Prefix',
       'Suffix', 'Credential', 'PracticeAddress', 'PracticeAddress2',
       'PracticeCity', 'PracticeState', 'PracticeZip', 'PracticeCountry',
       'PracticePhoneNum', 'PracticeFaxNum', 'ProviderGender', 'TaxonomyCode1',
       'TaxonomyCode2', 'TaxonomyCode3', 'TaxonomyCode4', 'TaxonomyCode5',
       'TaxonomyCode6', 'TaxonomyCode7', 'TaxonomyCode8', 'TaxonomyCode9',
       'TaxonomyCode10', 'TaxonomyCode11', 'TaxonomyCode12', 'TaxonomyCode13',
       'TaxonomyCode14', 'TaxonomyCode15']
df = pd.read_csv('filtered_npi_registry.csv',index_col=0,usecols=col)
df = df.reset_index()
# Out:
# /var/folders/j9/zypfn3lx7n72zyzrpnq_sqkr0000gn/T/ipykernel_70583/3902395503.py:9: DtypeWarning: Columns (27,28,29,30,31,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('filtered_npi_registry.csv',index_col=0,usecols=col)

# %% [markdown]
# ### Generate geocoding scripts

# %%
addresses = df[['NPI','PracticeAddress','PracticeCity','PracticeState','PracticeZip']]
for idx, chunk in enumerate(np.array_split(addresses,40)):
    chunk.to_csv(f"addresses{idx}.csv",index=False,header=False)
for i in range(0,40):
    print(f"!curl --form addressFile=@addresses{i}.csv --form benchmark=\"Public_AR_Current\"  https://geocoding.geo.census.gov/geocoder/locations/addressbatch --output geocodingResults/addresses{i}out.csv")

# %% [markdown]
# ### Join all output together

# %%
path = '/Users/sarahrodenbeck/Documents/MSDS/MSDS498 - Capstone/Cervical_Cancer_Risk_Assessment/FindProviderFeature/geocodingResults'
cols = ['NPI','Address','isMatch','isExact','AddressFound','LonLat','TigerLineID','Side']
all_files = glob.glob(os.path.join(path,"*.csv"))
li = []
for f in all_files:
    df = pd.read_csv(f,header=None,names=cols)
    li.append(df)

geocode_df = pd.concat(li,axis=0,ignore_index=True)

# %%
geocode_match = geocode_df[geocode_df['isMatch']=='Match']
geocode_match[['LON', 'LAT']] = geocode_match['LonLat'].str.split(',', 1, expand=True)

# %%
geocode_match
# Out:
#                NPI                                            Address isMatch  \
# 0       1952577819           1170 S EAST AVE, OAK PARK, IL, 603042143   Match
# 2       1801811716                     275 SEVENTH AVE, NY, NY, 10001   Match
# 3       1780684019             550 GAGE BLVD, RICHLAND, WA, 993529532   Match
# 4       1003819053           436 HINSDALE RD, CAMILLUS, NY, 130311648   Match
# 5       1871513564         11100 EUCLID AVE, CLEVELAND, OH, 441061716   Match
# ...            ...                                                ...     ...
# 394518  1023038155       3501 N MACARTHUR BLVD, IRVING, TX, 750623636   Match
# 394520  1912929928       307 SAINT JOHNS WAY, LEWISTON, ID, 835012435   Match
# 394521  1407960446  728 PACIFIC AVE STE 611, SAN FRANCISCO, CA, 94...   Match
# 394523  1336184613   1540 SPRING VALLEY DR, HUNTINGTON, WV, 257049300   Match
# 394524  1790715050       1111 CHESTNUT ST, NELSONVILLE, OH, 457641436   Match
#
#           isExact                                  AddressFound  \
# 0       Non_Exact          1170 S EAST AVE, OAK PARK, IL, 60304
# 2           Exact              275 7TH AVE, NEW YORK, NY, 10001
# 3           Exact            550 GAGE BLVD, RICHLAND, WA, 99352
# 4           Exact          436 HINSDALE RD, CAMILLUS, NY, 13031
# 5           Exact        11100 EUCLID AVE, CLEVELAND, OH, 44106
# ...           ...                                           ...
# 394518  Non_Exact      3501 N MACARTHUR BLVD, IRVING, TX, 75062
# 394520      Exact         307 ST JOHNS WAY, LEWISTON, ID, 83501
# 394521      Exact     728 PACIFIC AVE, SAN FRANCISCO, CA, 94133
# 394523      Exact  1540 SPRING VALLEY DR, HUNTINGTON, WV, 25704
# 394524      Exact      1111 CHESTNUT ST, NELSONVILLE, OH, 45764
#
#                                         LonLat  TigerLineID Side  \
# 0         -87.78889390499995,41.86642949700007  605103423.0    L
# 2         -73.99429134499997,40.74595244400007   59653388.0    R
# 3       -119.26166515499995,46.227124229000026  175008930.0    L
# 4        -76.26534634899997,43.050668114000075  640456402.0    R
# 5         -81.60805145599994,41.50662616000005  638278041.0    L
# ...                                        ...          ...  ...
# 394518   -96.95904881899997,32.852430351000066  617055072.0    L
# 394520   -117.02652766699998,46.41779947900005  173130432.0    R
# 394521   -122.40751166399997,37.79682395400005  639023945.0    R
# 394523    -82.51809241699993,38.38406918700008   57203084.0    L
# 394524    -82.21891245699999,39.44934869800005   37093251.0    L
#
#                         Lon                 Lat
# 0        -87.78889390499995   41.86642949700007
# 2        -73.99429134499997   40.74595244400007
# 3       -119.26166515499995  46.227124229000026
# 4        -76.26534634899997  43.050668114000075
# 5        -81.60805145599994   41.50662616000005
# ...                     ...                 ...
# 394518   -96.95904881899997  32.852430351000066
# 394520  -117.02652766699998   46.41779947900005
# 394521  -122.40751166399997   37.79682395400005
# 394523   -82.51809241699993   38.38406918700008
# 394524   -82.21891245699999   39.44934869800005
#
# [310912 rows x 10 columns]

# %% [markdown]
# ### Add lat/lon info to original dataframe

# %%
df = pd.merge(df,geocode_match[['NPI','LON','LAT']], on='NPI',how='left')

# %%
matches = df[df['LON'].isna()==False]

# %%
df.to_csv('npi_registry_census_geocode.csv')

# %% [markdown]
# ### Create postgresql database

# %%
url = 'postgresql+psycopg2://postgres:password@localhost/npiProviders'
engine = create_engine(url)
matches.to_sql('npi_registry',url,if_exists='replace',index=False)
# Out:
# 912

# %% [markdown]
# ### Test Queries and Validation

# %%
query = 'SELECT count(*) FROM npi_registry;'
pd.read_sql(query,engine)
# Out:
#     count
# 0  310912

# %%
query = 'SELECT * \
        FROM npi_registry \
        WHERE CAST("PracticeZip" as TEXT) like \'46236%%\';'
pd.read_sql(query,engine)
# Out:
#            NPI    LastName FirstName MiddleName Prefix Suffix Credential  \
# 0   1770004954      GIFFEN   MICHAEL       None   None   None         DO
# 1   1942253208       BRADY   TIMOTHY          B   None   None         MD
# 2   1669017117  RETHERFORD    RACHEL       None   None   None         PA
# 3   1477999233      GELATT   MICHAEL          P   None   None         DO
# 4   1962479923     LISANTI    JOSEPH          P    DR.   None         DO
# 5   1134765993   VARELDZIS     BASIL       None    DR.   None         MD
# 6   1407111339         LEE     JASON     DANIEL   None   None       M.D.
# 7   1528089844    LOVELESS  DANYELLE          M   None   None         MD
# 8   1669496162        LYNN   WILLIAM          J   None   None         MD
# 9   1144242124   VASILCHEK    DANICA          M   None   None         MD
# 10  1760496772   ROBINETTE  JENNIFER          S   None   None         MD
# 11  1396752226     STOOKEY   MICHELE          R   None   None         MD
#
#               PracticeAddress PracticeAddress2  PracticeCity PracticeState  \
# 0   8150 OAKLANDON RD STE 130             None  INDIANAPOLIS            IN
# 1            9443 E. 38TH ST.             None  INDIANAPOLIS            IN
# 2   8150 OAKLANDON RD STE 130             None  INDIANAPOLIS            IN
# 3           8150 OAKLANDON RD        SUITE 130  INDIANAPOLIS            IN
# 4         9347 PENDLETON PIKE             None  INDIANAPOLIS            IN
# 5      9125 NAUTICAL WATCH DR             None  INDIANAPOLIS            IN
# 6   8150 OAKLANDON RD STE 130             None  INDIANAPOLIS            IN
# 7           8150 OAKLANDON RD        SUITE 130  INDIANAPOLIS            IN
# 8           8150 OAKLANDON RD        SUITE 130  INDIANAPOLIS            IN
# 9           8150 OAKLANDON RD        SUITE 130  INDIANAPOLIS            IN
# 10          8150 OAKLANDON RD        SUITE 130  INDIANAPOLIS            IN
# 11          8150 OAKLANDON RD        SUITE 130  INDIANAPOLIS            IN
#
#     PracticeZip PracticeCountry  PracticePhoneNum  PracticeFaxNum  \
# 0     462369554              US        3176211111      3176211110
# 1     462362132              US        3178902100      3178902171
# 2     462369554              US        3176211111      3176211110
# 3     462369525              US        3176211111      3176211110
# 4     462362768              US        3176123193      3176123270
# 5     462369036              US        3179192846              -1
# 6     462369554              US        3176211111      3176211110
# 7     462369554              US        3176211111      3176211110
# 8     462369554              US        3176211111      3176211110
# 9     462369554              US        3176211111      3176217110
# 10    462369554              US        3176217111      3176217110
# 11    462369554              US        3176217111      3176217110
#
#    ProviderGender TaxonomyCode1 TaxonomyCode2 TaxonomyCode3 TaxonomyCode4  \
# 0               M    207Q00000X    207Q00000X          None          None
# 1               M    208000000X    207R00000X          None          None
# 2               F    363A00000X    207Q00000X          None          None
# 3               M    390200000X    207Q00000X          None          None
# 4               M    207Q00000X          None          None          None
# 5               M    207Q00000X    2083A0300X    2084P0015X          None
# 6               M    390200000X    207Q00000X          None          None
# 7               F    207Q00000X          None          None          None
# 8               M    207Q00000X          None          None          None
# 9               F    207Q00000X          None          None          None
# 10              F    207Q00000X          None          None          None
# 11              F    207Q00000X          None          None          None
#
#    TaxonomyCode5 TaxonomyCode6 TaxonomyCode7 TaxonomyCode8 TaxonomyCode9  \
# 0           None          None          None          None          None
# 1           None          None          None          None          None
# 2           None          None          None          None          None
# 3           None          None          None          None          None
# 4           None          None          None          None          None
# 5           None          None          None          None          None
# 6           None          None          None          None          None
# 7           None          None          None          None          None
# 8           None          None          None          None          None
# 9           None          None          None          None          None
# 10          None          None          None          None          None
# 11          None          None          None          None          None
#
#    TaxonomyCode10 TaxonomyCode11 TaxonomyCode12 TaxonomyCode13 TaxonomyCode14  \
# 0            None           None           None           None           None
# 1            None           None           None           None           None
# 2            None           None           None           None           None
# 3            None           None           None           None           None
# 4            None           None           None           None           None
# 5            None           None           None           None           None
# 6            None           None           None           None           None
# 7            None           None           None           None           None
# 8            None           None           None           None           None
# 9            None           None           None           None           None
# 10           None           None           None           None           None
# 11           None           None           None           None           None
#
#    TaxonomyCode15                 Lon                 Lat
# 0            None  -85.95714892899997   39.90479400100003
# 1            None  -86.00172876599999   39.82614653600007
# 2            None  -85.95714892899997   39.90479400100003
# 3            None  -85.95714892899997   39.90479400100003
# 4            None  -86.00382091599994   39.84748465500007
# 5            None  -85.96805080499996  39.919617405000054
# 6            None  -85.95714892899997   39.90479400100003
# 7            None  -85.95714892899997   39.90479400100003
# 8            None  -85.95714892899997   39.90479400100003
# 9            None  -85.95714892899997   39.90479400100003
# 10           None  -85.95714892899997   39.90479400100003
# 11           None  -85.95714892899997   39.90479400100003

# %%
matches[(matches['PracticeZip']>=462360000) & (matches['PracticeZip']<=462369999)]
# Out:
#                NPI    LastName FirstName MiddleName Prefix Suffix Credential  \
# 186097  1962479923     LISANTI    JOSEPH          P    DR.    NaN         DO
# 236690  1134765993   VARELDZIS     BASIL        NaN    DR.    NaN         MD
# 260824  1477999233      GELATT   MICHAEL          P    NaN    NaN         DO
# 261590  1407111339         LEE     JASON     DANIEL    NaN    NaN       M.D.
# 261595  1528089844    LOVELESS  DANYELLE          M    NaN    NaN         MD
# 261597  1669496162        LYNN   WILLIAM          J    NaN    NaN         MD
# 262102  1760496772   ROBINETTE  JENNIFER          S    NaN    NaN         MD
# 262381  1396752226     STOOKEY   MICHELE          R    NaN    NaN         MD
# 262500  1144242124   VASILCHEK    DANICA          M    NaN    NaN         MD
# 270464  1770004954      GIFFEN   MICHAEL        NaN    NaN    NaN         DO
# 312584  1669017117  RETHERFORD    RACHEL        NaN    NaN    NaN         PA
# 321919  1942253208       BRADY   TIMOTHY          B    NaN    NaN         MD
#
#                   PracticeAddress PracticeAddress2  PracticeCity  \
# 186097        9347 PENDLETON PIKE              NaN  INDIANAPOLIS
# 236690     9125 NAUTICAL WATCH DR              NaN  INDIANAPOLIS
# 260824          8150 OAKLANDON RD        SUITE 130  INDIANAPOLIS
# 261590  8150 OAKLANDON RD STE 130              NaN  INDIANAPOLIS
# 261595          8150 OAKLANDON RD        SUITE 130  INDIANAPOLIS
# 261597          8150 OAKLANDON RD        SUITE 130  INDIANAPOLIS
# 262102          8150 OAKLANDON RD        SUITE 130  INDIANAPOLIS
# 262381          8150 OAKLANDON RD        SUITE 130  INDIANAPOLIS
# 262500          8150 OAKLANDON RD        SUITE 130  INDIANAPOLIS
# 270464  8150 OAKLANDON RD STE 130              NaN  INDIANAPOLIS
# 312584  8150 OAKLANDON RD STE 130              NaN  INDIANAPOLIS
# 321919           9443 E. 38TH ST.              NaN  INDIANAPOLIS
#
#        PracticeState  PracticeZip PracticeCountry  PracticePhoneNum  \
# 186097            IN    462362768              US        3176123193
# 236690            IN    462369036              US        3179192846
# 260824            IN    462369525              US        3176211111
# 261590            IN    462369554              US        3176211111
# 261595            IN    462369554              US        3176211111
# 261597            IN    462369554              US        3176211111
# 262102            IN    462369554              US        3176217111
# 262381            IN    462369554              US        3176217111
# 262500            IN    462369554              US        3176211111
# 270464            IN    462369554              US        3176211111
# 312584            IN    462369554              US        3176211111
# 321919            IN    462362132              US        3178902100
#
#         PracticeFaxNum ProviderGender TaxonomyCode1 TaxonomyCode2  \
# 186097      3176123270              M    207Q00000X           NaN
# 236690              -1              M    207Q00000X    2083A0300X
# 260824      3176211110              M    390200000X    207Q00000X
# 261590      3176211110              M    390200000X    207Q00000X
# 261595      3176211110              F    207Q00000X           NaN
# 261597      3176211110              M    207Q00000X           NaN
# 262102      3176217110              F    207Q00000X           NaN
# 262381      3176217110              F    207Q00000X           NaN
# 262500      3176217110              F    207Q00000X           NaN
# 270464      3176211110              M    207Q00000X    207Q00000X
# 312584      3176211110              F    363A00000X    207Q00000X
# 321919      3178902171              M    208000000X    207R00000X
#
#        TaxonomyCode3 TaxonomyCode4 TaxonomyCode5 TaxonomyCode6 TaxonomyCode7  \
# 186097           NaN           NaN           NaN           NaN           NaN
# 236690    2084P0015X           NaN           NaN           NaN           NaN
# 260824           NaN           NaN           NaN           NaN           NaN
# 261590           NaN           NaN           NaN           NaN           NaN
# 261595           NaN           NaN           NaN           NaN           NaN
# 261597           NaN           NaN           NaN           NaN           NaN
# 262102           NaN           NaN           NaN           NaN           NaN
# 262381           NaN           NaN           NaN           NaN           NaN
# 262500           NaN           NaN           NaN           NaN           NaN
# 270464           NaN           NaN           NaN           NaN           NaN
# 312584           NaN           NaN           NaN           NaN           NaN
# 321919           NaN           NaN           NaN           NaN           NaN
#
#        TaxonomyCode8 TaxonomyCode9 TaxonomyCode10 TaxonomyCode11  \
# 186097           NaN           NaN            NaN            NaN
# 236690           NaN           NaN            NaN            NaN
# 260824           NaN           NaN            NaN            NaN
# 261590           NaN           NaN            NaN            NaN
# 261595           NaN           NaN            NaN            NaN
# 261597           NaN           NaN            NaN            NaN
# 262102           NaN           NaN            NaN            NaN
# 262381           NaN           NaN            NaN            NaN
# 262500           NaN           NaN            NaN            NaN
# 270464           NaN           NaN            NaN            NaN
# 312584           NaN           NaN            NaN            NaN
# 321919           NaN           NaN            NaN            NaN
#
#        TaxonomyCode12 TaxonomyCode13 TaxonomyCode14 TaxonomyCode15  \
# 186097            NaN            NaN            NaN            NaN
# 236690            NaN            NaN            NaN            NaN
# 260824            NaN            NaN            NaN            NaN
# 261590            NaN            NaN            NaN            NaN
# 261595            NaN            NaN            NaN            NaN
# 261597            NaN            NaN            NaN            NaN
# 262102            NaN            NaN            NaN            NaN
# 262381            NaN            NaN            NaN            NaN
# 262500            NaN            NaN            NaN            NaN
# 270464            NaN            NaN            NaN            NaN
# 312584            NaN            NaN            NaN            NaN
# 321919            NaN            NaN            NaN            NaN
#
#                        Lon                 Lat
# 186097  -86.00382091599994   39.84748465500007
# 236690  -85.96805080499996  39.919617405000054
# 260824  -85.95714892899997   39.90479400100003
# 261590  -85.95714892899997   39.90479400100003
# 261595  -85.95714892899997   39.90479400100003
# 261597  -85.95714892899997   39.90479400100003
# 262102  -85.95714892899997   39.90479400100003
# 262381  -85.95714892899997   39.90479400100003
# 262500  -85.95714892899997   39.90479400100003
# 270464  -85.95714892899997   39.90479400100003
# 312584  -85.95714892899997   39.90479400100003
# 321919  -86.00172876599999   39.82614653600007
